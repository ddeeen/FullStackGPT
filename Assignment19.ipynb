# %%
from openai import OpenAI, AssistantEventHandler
from langchain.retrievers import WikipediaRetriever
from langchain.tools import DuckDuckGoSearchResults
from langchain.document_loaders import WebBaseLoader
import json
import os

def search_wiki(inputs):
    topic = inputs["term"]
    retriever = WikipediaRetriever(
        top_k_result=4,
    )
    docs = retriever.invoke(topic)
    return "\n".join([doc.page_content for doc in docs])

def search_duckduckgo(inputs):
    # print("search_duckduckgo")
    query = inputs["query"]
    search = DuckDuckGoSearchResults()
    str = search.invoke(query)
    find_s_string = "link: https://"
    find_e_string = "]"
    del_string = "link: "
    s_index = str.find(find_s_string)
    e_index = 0
    urls = []
    while s_index != -1:
        s_index += e_index
        e_index = str[s_index:].find(find_e_string) + s_index
        urls.append(str[s_index + len(del_string):e_index])
        s_index = str[e_index:].find(find_s_string)
    return json.dumps({"urls":"\n".join(urls)})

def web_scrapping(inputs):
    urls = inputs["urls"]
    urls_list = urls.split("|")
    if len(urls_list) >= 2:
        loader = WebBaseLoader(urls_list[:2])
    else:
        loader = WebBaseLoader(urls_list)
    docs = loader.load()
    return "\n\n".join([doc.page_content.replace("\n", " ").replace("  ", " ") for doc in docs])

def save_content_to_txt(inputs):
    content = inputs["content"]
    filename = inputs["filename"]
    folder_dir = "./.cache/agent"
    os.makedirs(folder_dir, exist_ok=True)
    with open(f"{folder_dir}/{filename}.txt", "w", encoding="utf-8") as file:
        file.write(content)
    return inputs["content"]

functions_map = {
    "search_wiki":search_wiki,
    "search_duckduckgo":search_duckduckgo,
    "web_scrapping":web_scrapping,
    "save_content_to_txt":save_content_to_txt,
}

functions = [
    {
        "type":"function",
        "function":{
            "name":"search_wiki",
            "description":"Receives a single term, searches Wikipedia, and returns information about that term.",
            "parameters":{
                "type":"object",
                "properties":{
                    "term":{
                        "type":"string",
                        "description":"The term you will search for on Wikipedia."
                    },
                },
                "required":["term"],
            }
        }
    },
    {
        "type":"function",
        "function":{
            "name":"search_duckduckgo",
            "description":"It receives a query, searches the input content using DuckDuckGo, and returns list of the website address(url)",
            "parameters":{
                "type":"object",
                "properties":{
                    "query":{
                        "type":"string",
                        "description":"The query you will search for. Example query: Research about the XZ backdoor",
                    },
                },
                "required":["query"],
            }
        }
    },
    {
        "type":"function",
        "function":{
            "name":"web_scrapping",
            "description":"""This function accesses the specified URL and extracts information from them.
            This function receives URL list, scrapes the information from those URL, and returns web information.""",
            "parameters":{
                "type":"object",
                "properties":{
                    "urls":{
                        "type":"string",
                        "description":"url list to extracts web information. Example url list: 'https://en.wikipedia.org/wiki/URL|https://naver.com|https://daum.net'",
                    },
                },
                "required":["urls"],
            }
        }
    },
    {
        "type":"function",
        "function":{
            "name":"save_content_to_txt",
            "description":"This tool receives content and a filename and saves them as a text file.",
            "parameters":{
                "type":"object",
                "properties":{
                    "content":{
                        "type":"string",
                        "description":"Content to be saved as a text file.",
                    },
                    "filename":{
                        "type":"string",
                        "description":"Filename to save the content. A single word that contains the content.",
                    },
                },
                "required":["content", "filename"],
            }
        }
    }
]

# %%
client = OpenAI()
assistant = client.beta.assistants.create(
    name="Research Assistant",
    instructions="""
You are a research expert.
When you get a research request, decide between Wikipedia and DuckDuckGo.
Perform the search using the better option.
If one source lacks information, gather more from the other.
With DuckDuckGo, obtain the website's URL.
Use the URL to extract information from the site.
Write all collected content.
And save all collected content as a text file.
Name the file with the key term.
""",
    model="gpt-4o-mini",
    tools=functions,
)

# %%
assistant
assistant_id=assistant.id

# %%
thread = client.beta.threads.create(
    # messages=[
    #     {
    #         "role":"user",
    #         "content":"Research about the XZ backdoor",
    #     }
    # ]
)

# %%
thread
thread_id = thread.id

# %%
run = client.beta.threads.runs.create(
    thread_id=thread_id,
    assistant_id=assistant_id,
)
run_id = run.id
run

# %%
def get_run(run_id, thread_id):
    return client.beta.threads.runs.retrieve(
        run_id=run_id,
        thread_id=thread_id,
    )

def get_messages(thread_id):
    messages = client.beta.threads.messages.list(
        thread_id=thread_id,
    )
    messages = list(messages)
    messages.reverse()
    for message in messages:
        print(f"{message.role}:{message.content[0].text.value}")

def add_message(thread_id, content):
    return client.beta.threads.messages.create(
        thread_id=thread_id,
        role="user",
        content=content
    )

def get_tool_outputs(run_id, thread_id):
    run = get_run(run_id, thread_id)
    print("========run========\n", run, "\n===========================")
    if run.status == 'requires_action':
        outputs = []
        for action in run.required_action.submit_tool_outputs.tool_calls:
            action_id=action.id
            function = action.function
            # print(f"Calling function: {function.name} with args {function.arguments}")
            output = functions_map[function.name](json.loads(function.arguments))
            outputs.append({
                "output":output,
                "tool_call_id": action_id,
            })
    else:
        # expired될 경우를 생각해야함. 이 때는, 다시 message를 보내라고 얘기해줘야함.
        pass
    return outputs

def submit_tool_outputs(run_id, thread_id):
    output = get_tool_outputs(run_id, thread_id)
    client.beta.threads.runs.submit_tool_outputs(
        run_id=run_id,
        thread_id=thread_id,
        tool_outputs=output,
    )
    return output

# %%
get_run(run_id, thread_id).status
# Out:
# 'requires_action'

# %%
get_messages(thread_id)
# Out:
# user:Research about the XZ backdoor
# assistant:I have completed the research on the XZ backdoor. Here's a summary of the findings:
#
# ### XZ Utils Backdoor Overview
#
# #### Background
# In February 2024, a malicious backdoor was introduced to the Linux utility xz within the liblzma library in versions 5.6.0 and 5.6.1 by an account using the name "Jia Tan". This backdoor allows attackers with a specific Ed448 private key to have remote code execution capabilities on affected Linux systems. The issue was assigned a Common Vulnerabilities and Exposures (CVE) number, CVE-2024-3094, and received a CVSS score of 10.0, indicating a critical vulnerability.
#
# While xz is commonly present in most Linux distributions, it was noted that the compromised version had not yet been widely deployed to production systems, although it was found in development versions of major distributions. The discovery was made by the software developer Andres Freund, who reported it on March 29, 2024.
#
# Freund's investigation into a performance regression in Debian Sid uncovered that SSH connections were generating unexpectedly high CPU usage and causing errors in Valgrind, which led to the discovery of the backdoor. The attacker had obfuscated the code, which consisted of multiple stages that cooperatively functioned when incorporated into the operating system. This backdoor manipulates OpenSSH's SSH server daemon by abusing the systemd library, granting the attacker administrative access.
#
# #### Mechanism
# The malicious code in the affected XZ Utils software treats the exploit as dormant unless a particular third-party patch is used on the SSH server. When triggered, it can potentially undermine sshd authentication, enabling unauthorized access to the entire system.
#
# The exploit comprises two compressed test files that contain malicious binary code, which, while present in the Git repository, remain inactive unless extracted and injected into the program. Notably, the malicious code modifies the `RSA_public_decrypt` function in OpenSSH with a malicious version through the glibc IFUNC mechanism. Usually, OpenSSH does not load liblzma, but some Linux distributions' common third-party patches cause it to do so, thus facilitating the exploitation.
#
# #### Response
# In response to this security breach, the U.S. federal Cybersecurity and Infrastructure Security Agency (CISA) has recommended affected devices revert to a previous uncompromised version. Major Linux software vendors, including Red Hat, SUSE, and Debian, responded by reverting the affected packages to older, safe versions. GitHub temporarily disabled mirrors for the XZ repository before restoring them.
#
# Canonical postponed the beta release of Ubuntu 24.04 LTS by a week, with plans for a complete binary rebuild of all distribution packages as a precaution against potential vulnerabilities during compilation. Experts have expressed that if the backdoor had remained undetected, it could have significantly compromised numerous computers worldwide that use SSH.
#
# This incident raises concerns about the reliance on volunteer contributions for maintaining critical software infrastructure. It serves as a cautionary tale for the open-source community regarding project security and maintenance.
#
# ---
#
# This information has been saved as a text file named **XZ_backdoor.txt**. If you need further details or additional information, feel free to ask!
# user:Research about the XZ backdoor
# assistant:I have gathered extensive information about the XZ backdoor, which was a significant security incident that occurred in early 2024. Here’s a detailed overview of the findings:
#
# ### Overview of the XZ Backdoor
#
# #### Background
# In February 2024, a backdoor was introduced to the XZ Utils, a widely used open-source data compression utility for Linux and Unix-like operating systems. This malware was discovered in versions 5.6.0 and 5.6.1 of XZ Utils, which a user operating under the alias "Jia Tan" injected. The backdoor could allow attackers to remotely execute code on affected systems if they possessed a specified Ed448 private key. The vulnerability has been designated as CVE-2024-3094 and assigned a CVSS score of 10.0, indicating its critical severity.
#
# #### Discovery
# The backdoor was uncovered by developer Andres Freund, who encountered performance issues with SSH protocols while troubleshooting a Debian system. His investigations linked these performance problems to recent updates in XZ Utils, alerting the open-source community to the risks of supply chain attacks—the infiltration method where malicious code is placed within legitimate software.
#
# #### Mechanism of the Backdoor
# The malicious code altered the SSH functionality, permitting anyone with the predetermined encryption key to execute arbitrary code on a compromised system via SSH. The integration of this backdoor involved several programmatic hooks that activated when the liblzma library was utilized by the SSH daemon (sshd), which typically does not invoke liblzma by default. As such, the backdoor remained inactive until specific conditions were met, enabling diverse malicious activities, including malware installation and sensitive data extraction.
#
# ### The Persona of Jia Tan
# The individual behind the backdoor, identified as Jia Tan, spent years methodically integrating into open-source software development. They began contributing under the username JiaT75 in 2021 and gradually gained trust within the community before assuming control of XZ Utils. This synthetic persona was a clever disguise for malicious intent.
#
# #### Analysis and Theories
# There are speculations that Jia Tan may not be a singular individual but represent a front for a state-sponsored hacking entity due to the sophisticated nature and long-term planning behind this initiative. Experts have proposed links to APT29, a group associated with Russian intelligence, as evidenced by the infiltration tactics and patterns seen in the code.
#
# ### Community Impact and Response
# The detection of the XZ backdoor resulted in rapid action from both the open-source community and various Linux distributions, recommending a rollback to earlier, untainted software versions. The ongoing investigations aim to unravel the complete impact and potential consequences of this backdoor, highlighting the paramount importance of trust and security in the open-source ecosystem, which heavily relies on collaborative contributions for maintaining critical infrastructure.
#
# Organizations and developers are encouraged to increase vigilance regarding code submissions to key projects, implementing standardized security audits to combat potential future supply chain threats.
#
# This information has been saved as a text file named **XZ_backdoor.txt**. If you require additional details or exploration into specific areas, please let me know!
# user:Research about the XZ backdoor
# assistant:I have completed the research on the XZ backdoor, which was a critical security incident identified in early 2024. Here’s a detailed summary of the information gathered about it:
#
# ### Overview of the XZ Backdoor
#
# #### Background
# In February 2024, a malicious backdoor was introduced into XZ Utils, a widely used open-source data compression utility for Linux and other Unix-like operating systems. This backdoor was embedded in versions 5.6.0 and 5.6.1 and could allow remote code execution for anyone possessing a specific Ed448 private key. The vulnerability received the CVE designation CVE-2024-3094 with a CVSS score of 10.0, highlighting its critical severity.
#
# The backdoor was discovered by a developer, Andres Freund, during an investigation into performance issues with SSH connections on a Debian system. The discovery raised alarms in the open-source software community regarding potential supply chain vulnerabilities.
#
# #### Discovery
# Freund noticed unusual CPU usage and errors associated with memory management, which ultimately led him to uncover the malicious code associated with the XZ Utils updates. This prompted further investigation into the matter, raising concerns about supply chain attacks where legitimate software is compromised to distribute malicious code.
#
# #### Mechanism of the Backdoor
# The backdoor affected the SSH daemon (sshd) functionality, allowing an attacker with the appropriate private key to execute arbitrary code on compromised systems. It consisted of two compressed test files that contained the malicious code, remaining dormant unless specific conditions, such as integrating with a specific third-party SSH patch, were met.
#
# The sophistication of the backdoor design allowed it to evade detection, modifying execution flows through internal library linking. Although OpenSSH generally did not load the liblzma library, patches made by various Linux distributions enabled this functionality, thus facilitating exploitation.
#
# #### The Persona of Jia Tan
# The individual behind the backdoor operated under the alias Jia Tan, orchestrating a multi-year infiltration into open-source software development. Jia Tan first appeared in 2021 and gradually gained trust within the community, contributing significantly to the XZ Utils project, ultimately embedding the malicious code.
#
# Many experts suspect Jia Tan may symbolize a front for a state-sponsored hacking group, given the complexity of the infiltration and operational security methods exhibited. Links have been drawn to groups like APT29, which is associated with Russian intelligence.
#
# #### Community Impact and Response
# Following the backdoor's discovery, the open-source community reacted promptly, recommending the roll back to untainted software versions. Many Linux distributions acted quickly to revert their changes to eliminate the vulnerability, reinforcing the need for vigilance and security audits in open-source projects.
#
# ### Conclusion
# The XZ backdoor incident serves as a significant case study in the vulnerabilities present in open-source software ecosystems and the tactics used by actors targeting software supply chains. It emphasizes the critical necessity for ongoing scrutiny and rigorous security practices within open-source projects to uphold their integrity and security.
#
# This information has been saved as a text file named **XZ_backdoor.txt**. If you need further details or specific insights on any aspect, feel free to ask!
# user:Research about the Onepiece

# %%
add_message(thread_id, "Research about the Onepiece")

# %%
print(get_run(run_id, thread_id))

# %%
submit_tool_outputs(run_id, thread_id)
# Out:
# ========run========
#  Run(id='run_1kw4nMZIzw6b4DskD3UsJBAk', assistant_id='asst_85obwClXjFOH4vFg5oX3lT7F', cancelled_at=None, completed_at=None, created_at=1726406183, expires_at=1726406783, failed_at=None, incomplete_details=None, instructions="\nYou are a research expert.\nWhen you get a research request, decide between Wikipedia and DuckDuckGo.\nPerform the search using the better option.\nIf one source lacks information, gather more from the other.\nWith DuckDuckGo, obtain the website's URL.\nUse the URL to extract information from the site.\nWrite all collected content.\nAnd save all collected content as a text file.\nName the file with the key term.\n", last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o-mini', object='thread.run', parallel_tool_calls=True, required_action=RequiredAction(submit_tool_outputs=RequiredActionSubmitToolOutputs(tool_calls=[RequiredActionFunctionToolCall(id='call_Kf3l6Yq0QlNQehicgEhGrHGS', function=Function(arguments='{"content":"### Overview of One Piece\\n\\n#### General Information\\n**One Piece** is a Japanese manga series created by **Eiichiro Oda**. It has been serialized in Shueisha\'s shōnen manga magazine *Weekly Shōnen Jump* since **July 1997**. The narrative follows the adventures of **Monkey D. Luffy** and his crew, the **Straw Hat Pirates**, as they set out to explore the Grand Line in pursuit of the legendary treasure known as the \\"One Piece\\" to claim the title of the next **King of the Pirates**.\\n\\nBy July 2024, the manga had been compiled into **109 tankōbon volumes** and has been praised for its storytelling, character development, humor, and world-building. The anime adaptation, produced by **Toei Animation**, began broadcasting in **1999** and has since seen a plethora of films and specials produced.\\n\\nOne Piece has evolved into one of the most celebrated manga and anime franchises globally, receiving numerous accolades for its artistic achievements. By August 2022, it was noted to have over **516.6 million copies** in circulation, making it the best-selling manga series in history. It has also set multiple records for publishing, including the highest initial print run of any title in Japan.\\n\\n#### Synopsis\\n**Setting**: The One Piece world encompasses a variety of races, including humans, dwarves, giants, and more. The world is governed by the **World Government**, with pirates as significant adversaries to their rule. **Devil Fruits** grant extraordinary abilities to those who consume them, while **Haki** provides combat enhancements to users.\\n\\n#### Characters:\\n- **Monkey D. Luffy**: The main protagonist, a boy with rubber-like abilities after eating a Devil Fruit.\\n- **Roronoa Zoro**: A swordsman who joins Luffy\'s crew.\\n- **Nami**: The navigator of the Straw Hat Pirates.\\n- **Usopp**, **Sanji**, **Tony Tony Chopper**, and others who further populate Luffy\'s crew with distinct abilities and backgrounds.\\n\\n#### Media Adaptations\\n- **Anime Series**: The One Piece anime adaptation has aired over **1,119 episodes** as of September 2024.\\n- **Films**: A total of **15 animated feature films** have been released to date, typically with original plots or retellings of manga arcs.\\n- **Merchandise**: A multitude of merchandise, including trading cards and video games, has been produced to complement the franchise.\\n- **Live Action**: A live-action adaptation was released on **Netflix** in 2023.\\n\\n### Popularity and Cultural Impact\\nOne Piece has garnered acclaim for its intricate world-building and character dynamics, leading to its recognition as one of the premier manga series alongside historic titles like **Naruto** and **Dragon Ball**. It has consistently been at the forefront of sales charts in both Japan and internationally.\\n\\n#### Conclusion\\nAs a staple of the manga and anime community, One Piece continues to resonate with fans worldwide, and the ongoing story keeps engaging new audiences, building on its leg ...
# ===========================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 submit_tool_outputs(run_id, thread_id)
#
# Cell In[257], line 49, in submit_tool_outputs(run_id, thread_id)
#      43 output = get_tool_outputs(run_id, thread_id)
#      44 client.beta.threads.runs.submit_tool_outputs(
#      45     run_id=run_id,
#      46     thread_id=thread_id,
#      47     tool_outputs=output,
#      48 )
# ---> 49 return output["output"]
#
# TypeError: list indices must be integers or slices, not str
